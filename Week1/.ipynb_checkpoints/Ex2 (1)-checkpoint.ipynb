# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
rawdata = np.fromfile('D:/學校/數位視訊技術/test_img/LenaGray_raw.raw',dtype=np.uint8)

# %%
rawdata.shape
# Out:
# (262144,)

# %%
img = rawdata.reshape([512,512])

# %%
img.shape
# Out:
# (512, 512)

# %%
plt.imshow(img,cmap='gray')
plt.show()

# %%
h, w = 512, 512

# %%
nh, nw = 1024, 1024

# %%
scale = int(nh/h)

# %%
nimg = np.zeros([1024,1024])

# %%
for ni in range(0,nh,2):
    for nj in range(0,nw,2):
        i = int(ni/scale)
        j = int(nj/scale)
        nimg[ni,nj] = img[i,j]
        nimg[ni,nj+1] = img[i,j]
        nimg[ni+1,nj] = img[i,j]
        nimg[ni+1,nj+1] = img[i,j]

# %%
plt.imshow(nimg,cmap='gray')
plt.show()
