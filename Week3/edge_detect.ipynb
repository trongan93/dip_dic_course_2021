# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread('iron_man.jpg',0)
laplacian = cv.Laplacian(img,cv.CV_64F)

# %%
sobelx = cv.Sobel(img,cv.CV_64F,1,0,ksize=5)
sobely = cv.Sobel(img,cv.CV_64F,0,1,ksize=5)

# %%
plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
plt.imshow(img,cmap = 'gray')
plt.show()

# %%
plt.imshow(laplacian,cmap = 'gray')
plt.show()

# %%
plt.imshow(sobelx,cmap = 'gray')
plt.show()

# %%
plt.imshow(sobely,cmap = 'gray')
plt.show()

# %%
edges = cv.Canny(img,100,200)

plt.title('Gray Image')
plt.imshow(img,cmap = 'gray')
plt.show()

plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image')
plt.show()

# %%
# ret,thresh1 = cv.threshold(img,127,255,cv.THRESH_BINARY)
ret,thresh1 = cv.threshold(img,127,255,0)
plt.imshow(thresh1,'gray',vmin=0,vmax=255)
plt.show()

# %%
# blur = cv.blur(img,(5,5))
median = cv.medianBlur(img,5)
plt.imshow(blur,'gray')
plt.show()

# %%
from skimage.util import random_noise
# Add salt and pepper noise to the image
noise_img = random_noise(img, mode="s&p",amount=0.3)
noise_img = np.array(255*noise_img, dtype = 'uint8')
plt.imshow(noise_img,'gray')
plt.show()

# %%
# Apply median filter
median = cv.medianBlur(noise_img,5)
plt.imshow(median,'gray')
plt.show()

# %%
edges_blur = cv.Canny(median,100,200)
plt.imshow(edges_blur,'gray')
plt.show()

# %%
test_noise = cv.imread('test_noise.jpg',0)
plt.imshow(test_noise,'gray')
plt.show()
edges_test_noise = cv.Canny(test_noise,100,200)
plt.imshow(edges_test_noise,'gray')
plt.show()

# %%
median_noise = cv.medianBlur(test_noise,9)
plt.imshow(median_noise,'gray')
plt.show()

edges_median_noise = cv.Canny(median_noise,100,200)
plt.imshow(edges_median_noise,'gray')
plt.show()
